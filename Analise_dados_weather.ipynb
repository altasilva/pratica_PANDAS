# %%
import pandas as pd

# %%
weather = pd.read_csv("Weather Data.csv")
weather.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
weather.max()
# Out:
# Date/Time                    9/9/2012 9:00
# Temp_C                                33.0
# Dew Point Temp_C                      24.4
# Rel Hum_%                              100
# Wind Speed_km/h                         83
# Visibility_km                         48.3
# Press_kPa                           103.65
# Weather             Thunderstorms,Rain,Fog
# dtype: object

# %%
weather['Temp_C'].mean()
# Out:
# 8.79814435336981

# %%
weather["Rel Hum_%"].mean()
# Out:
# 67.43169398907104

# %%
weather['Weather']
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object

# %%
import plotly.express as px

# %%
weather['Temp_C'].plot()
# Out:
# <AxesSubplot:>

# %%
px.histogram(weather, x='Temp_C', color='Weather')
# Out:
# <div>                            <div id="5fb1c76c-894e-4ce1-9972-7f30a5ea79cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fb1c76c-894e-4ce1-9972-7f30a5ea79cd")) {                    Plotly.newPlot(                        "5fb1c76c-894e-4ce1-9972-7f30a5ea79cd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Weather=Fog<br>Temp_C=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Fog","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fog","offsetgroup":"Fog","orientation":"v","showlegend":true,"x":[-1.8,-1.8,-1.5,-1.4,-1.5,-1.4,-1.4,-1.3,-1.0,-0.5,-0.2,0.2,0.8,1.8,-1.5,2.1,-14.5,-13.0,-11.2,1.2,1.4,0.8,0.5,0.4,0.5,0.6,-4.1,3.9,4.9,6.5,5.3,0.7,0.7,0.6,0.8,0.8,0.7,0.6,0.8,1.0,2.5,3.3,4.0,3.7,4.3,4.1,3.0,
# ...

# %%
px.histogram(weather, x='Rel Hum_%', color='Weather')
# Out:
# <div>                            <div id="b7740a17-29fa-4853-8dbc-7d9c2a4e3874" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7740a17-29fa-4853-8dbc-7d9c2a4e3874")) {                    Plotly.newPlot(                        "b7740a17-29fa-4853-8dbc-7d9c2a4e3874",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Weather=Fog<br>Rel Hum_%=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Fog","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fog","offsetgroup":"Fog","orientation":"v","showlegend":true,"x":[86,87,88,87,89,85,85,88,91,89,88,87,87,85,89,90,80,81,85,92,90,92,90,90,89,89,86,89,87,87,87,88,89,89,92,90,89,90,92,97,96,97,95,97,95,94,98,99,99,99,99,99,99,100,98,97,94,91,90,90,88,91,90,93,89,90,95,93
# ...

# %%
for coluna in weather:
  grafico = px.histogram(weather, x=coluna, color="Weather")
  grafico.show()
# Out:
# <div>                            <div id="5f72b35f-877a-4e66-9a14-22bafbfae2af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f72b35f-877a-4e66-9a14-22bafbfae2af")) {                    Plotly.newPlot(                        "5f72b35f-877a-4e66-9a14-22bafbfae2af",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Weather=Fog<br>Date/Time=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Fog","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fog","offsetgroup":"Fog","orientation":"v","showlegend":true,"x":["1/1/2012 0:00","1/1/2012 1:00","1/1/2012 4:00","1/1/2012 5:00","1/1/2012 6:00","1/1/2012 7:00","1/1/2012 8:00","1/1/2012 9:00","1/1/2012 10:00","1/1/2012 11:00","1/1/2012 12:00","1/1/2012 13:00","1/1/201
# ...

# %% [markdown]
# Selecionando as linhas com temperatura acima de 5 graus

# %%
weather[weather['Temp_C']>5]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23     1/1/2012 23:00     5.3               2.0         79               30
# 24      1/2/2012 0:00     5.2               1.5         77               35
# 1260  2/22/2012 12:00     5.2              -0.6         66               28
# 1261  2/22/2012 13:00     5.8              -1.1         61               22
# 1262  2/22/2012 14:00     6.1              -1.4         59               17
# ...               ...     ...               ...        ...              ...
# 8139   12/5/2012 3:00     7.8               6.7         93               24
# 8140   12/5/2012 4:00     7.2               4.8         85               15
# 8141   12/5/2012 5:00     6.6               4.1         84               17
# 8142   12/5/2012 6:00     5.7               2.7         81               24
# 8143   12/5/2012 7:00     5.2               0.4         71               30
#
#       Visibility_km  Press_kPa        Weather
# ...

# %% [markdown]
# Desta vez vamos selecionar as linhas com temperatura acima de 5 graus, mas apenas da coluna Temp_C

# %%
weather[weather['Temp_C']==0]['Temp_C']
# Out:
# 39      0.0
# 962     0.0
# 979     0.0
# 1236    0.0
# 1314    0.0
# 1315    0.0
# 1316    0.0
# 1326    0.0
# 1633    0.0
# 6862    0.0
# 7457    0.0
# 7474    0.0
# 7486    0.0
# 7978    0.0
# 7983    0.0
# 8271    0.0
# 8272    0.0
# 8281    0.0
# 8353    0.0
# 8783    0.0
# Name: Temp_C, dtype: float64

# %% [markdown]
# Agora vamos alterar as temperaturas iguais a 0 e alterar para 0.001, nesse caso será necessário usar o loc.

# %%
weather.loc[weather['Temp_C']==0,'Temp_C'] = 0.001
weather[weather['Temp_C']==0.001]['Temp_C']
# Out:
# 39      0.001
# 962     0.001
# 979     0.001
# 1236    0.001
# 1314    0.001
# 1315    0.001
# 1316    0.001
# 1326    0.001
# 1633    0.001
# 6862    0.001
# 7457    0.001
# 7474    0.001
# 7486    0.001
# 7978    0.001
# 7983    0.001
# 8271    0.001
# 8272    0.001
# 8281    0.001
# 8353    0.001
# 8783    0.001
# Name: Temp_C, dtype: float64
